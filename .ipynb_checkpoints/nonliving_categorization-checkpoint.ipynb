# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import cv2
import os

# %%
img = image.load_img("Multicategory_Nonliving/training/boat/A.jpg")
plt.imshow(img)
cv2.imread("Multicategory_Nonliving/training/boat/A.jpg").shape
# Out:
# (1060, 1600, 3)

# %%
#change range to -0.5 to 0.5?
train = ImageDataGenerator(rescale = 1/255)
validation = ImageDataGenerator(rescale = 1/255)

# %%
#figure out how to reshape with imagedatagenerator
#Flatten the images. Flatten each 28x28 image into a 28^2 = 784 dimensional 
#vector to pass into the neural network
#train = train.reshape((-1,784))
#test = test.reshape((-1,784))

# %%
#Validation dataset not being used...what to do with test dataset?
train_dataset = train.flow_from_directory('Multicategory_Nonliving/training',
                                         target_size = (200,200), 
                                         batch_size = 3, 
                                         class_mode = 'categorical')
validation_dataset = train.flow_from_directory('Multicategory_Nonliving/validation',
                                         target_size = (200,200), 
                                         batch_size = 3, 
                                         class_mode = 'categorical')
# Out:
# Found 15 images belonging to 3 classes.
# Found 6 images belonging to 3 classes.

# %%
model = tf.keras.models.Sequential([ tf.keras.layers.Conv2D(16,(3,3),activation = 'relu', input_shape = (200,200,3)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(32,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    ##
                                    tf.keras.layers.Flatten(),
                                    ##
                                    tf.keras.layers.Dense(512, activation = 'relu'),
                                    ##
                                    tf.keras.layers.Dense(3, activation = 'softmax')                                                      
                                    ])

# %%
model.compile(
    optimizer = RMSprop(lr= 0.001),
    loss = 'categorical_crossentropy', #uses classes that are > 2)
    metrics = ['accuracy']
)

# %%
model_fit = model.fit(train_dataset,
                     steps_per_epoch = 5,#The number of samples per gradient update for training 
                     epochs= 30,#The number of iterations over the entire dataset to train on
                     validation_data = validation_dataset)
# Out:
# Epoch 1/30
# 5/5 [==============================] - 1s 295ms/step - loss: 23.8128 - accuracy: 0.1333 - val_loss: 1.1157 - val_accuracy: 0.6667
# Epoch 2/30
# 5/5 [==============================] - 1s 243ms/step - loss: 1.0492 - accuracy: 0.4667 - val_loss: 1.0518 - val_accuracy: 0.3333
# Epoch 3/30
# 5/5 [==============================] - 1s 222ms/step - loss: 0.9784 - accuracy: 0.6667 - val_loss: 2.8271 - val_accuracy: 0.3333
# Epoch 4/30
# 5/5 [==============================] - 1s 216ms/step - loss: 0.8358 - accuracy: 0.8000 - val_loss: 0.8186 - val_accuracy: 0.8333
# Epoch 5/30
# 5/5 [==============================] - 1s 212ms/step - loss: 0.1858 - accuracy: 1.0000 - val_loss: 0.6568 - val_accuracy: 0.8333
# Epoch 6/30
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0403 - accuracy: 1.0000 - val_loss: 0.8400 - val_accuracy: 0.8333
# Epoch 7/30
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.9070 - val_accuracy: 0.8333
# Epoch 8/30
# 5/5 [==============================] - 1s 267ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5675 - val_accuracy: 0.6667
# Epoch 9/30
# 5/5 [==============================] - 1s 231ms/step - loss: 5.5091e-04 - accuracy: 1.0000 - val_loss: 1.5659 - val_accuracy: 0.5000
# Epoch 10/30
# 5/5 [==============================] - 1s 224ms/step - loss: 8.6618e-04 - accuracy: 1.0000 - val_loss: 0.5070 - val_accuracy: 0.6667
# Epoch 11/30
# 5/5 [==============================] - 1s 221ms/step - loss: 1.3395e-04 - accuracy: 1.0000 - val_loss: 0.4852 - val_accuracy: 0.6667
# Epoch 12/30
# 5/5 [==============================] - 1s 235ms/step - loss: 9.4646e-05 - accuracy: 1.0000 - val_loss: 0.5585 - val_accuracy: 0.6667
# Epoch 13/30
# 5/5 [==============================] - 1s 209ms/step - loss: 6.6408e-05 - accuracy: 1.0000 - val_loss: 0.4396 - val_accuracy: 0.8333
# Epoch 14/30
# 5/5 [==============================] - 1s 219ms/step - loss: 4.5097e-05 - accuracy: 1.0000 - val_loss: 0.4993 - val_accuracy: 0.8333
# Epoch 15/30
# 5/5 [==============================] - 1s 257ms/step - loss: 2.9126e-05 - accuracy: 1.0000 - val_loss: 0.4835 - val_accuracy: 0.8333
# Epoch 16/30
# 5/5 [==============================] - 1s 227ms/step - loss: 2.3714e-05 - accuracy: 1.0000 - val_loss: 0.4473 - val_accuracy: 0.8333
# Epoch 17/30
# 5/5 [==============================] - 1s 215ms/step - loss: 1.9001e-05 - accuracy: 1.0000 - val_loss: 0.5461 - val_accuracy: 0.6667
# Epoch 18/30
# 5/5 [==============================] - 1s 239ms/step - loss: 1.3430e-05 - accuracy: 1.0000 - val_loss: 0.4109 - val_accuracy: 0.8333
# Epoch 19/30
# 5/5 [==============================] - 1s 245ms/step - loss: 9.4810e-06 - accuracy: 1.0000 - val_loss: 0.5432 - val_accuracy: 0.8333
# Epoch 20/30
# 5/5 [==============================] - 1s 228ms/step - loss: 6.2624e-06 - accuracy: 1.0000 - val_loss: 0.4025 - val_accuracy: 0.8333
# Epoch 21/30
# 5/5 [==============================] - 1s 222ms/step - loss: 5.2690e-06 - accuracy: 1.0000 - val_loss: 0.6263 - val_accuracy: 0.8333
# Epoch 22/30
# 5/5 [==============================] - 1s 209ms/step - loss: 4.4981e-06 - accuracy: 1.0000 - val_loss: 0.3519 - val_accuracy: 0.8333
# Epoch 23/30
# 5/5 [==============================] - 1s 205ms/step - loss: 2.8531e-06 - accuracy: 1.0000 - val_loss: 0.4359 - val_accuracy: 0.8333
# Epoch 24/30
# 5/5 [==============================] - 1s 212ms/step - loss: 1.9630e-06 - accuracy: 1.0000 - val_loss: 0.4349 - val_accuracy: 0.8333
# Epoch 25/30
# 5/5 [==============================] - 1s 214ms/step - loss: 1.6689e-06 - accuracy: 1.0000 - val_loss: 0.3227 - val_accuracy: 0.8333
# Epoch 26/30
# 5/5 [==============================] - 1s 210ms/step - loss: 1.1285e-06 - accuracy: 1.0000 - val_loss: 0.5091 - val_accuracy: 0.8333
# Epoch 27/30
# 5/5 [==============================] - 1s 207ms/step - loss: 8.1062e-07 - accuracy: 1.0000 - val_loss: 0.3685 - val_accuracy: 0.8333
# Epoch 28/30
# 5/5 [==============================] - 1s 231ms/step - loss: 6.1989e-07 - accuracy: 1.0000 - val_loss: 0.4045 - val_accuracy: 0.8333
# Epoch 29/30
# 5/5 [==============================] - 1s 214ms/step - loss: 3.8942e-07 - accuracy: 1.0000 - val_loss: 0.3216 - val_accuracy: 0.8333
# Epoch 30/30
# 5/5 [==============================] - 1s 213ms/step - loss: 4.0531e-07 - accuracy: 1.0000 - val_loss: 0.4628 - val_accuracy: 0.8333

# %%
validation_dataset.class_indices
# Out:
# {'boat': 0, 'car': 1, 'plane': 2}

# %%
def listdir_nohidden(path):
    for f in os.listdir(path):
        if not f.startswith('.'):
            yield f

dir_path = 'Multicategory_Nonliving/testing'
for i in listdir_nohidden(dir_path):
    img = image.load_img(dir_path+'//'+i,target_size = (200,200))
    plt.imshow(img)
    plt.show()
    
    X = image.img_to_array(img)
    X = np.expand_dims(X, axis = 0)
    images = np.vstack([X])
    val = model.predict(images)
    #val is an ndarray, so argmax returns the index of the maximum value in each row (axis =1)
    #since these are binary digits, it returns the index where the value is 1, indicating the class index
    #there is also only one row, so it returns one value, appropriate for the if statement
    index = (np.argmax(val, axis = 1))
    if index == 0:
        print("Boat")
    elif index == 1:
        print("Car")
    else:
        print("Plane")
# Out:
# Boat
# Boat
# Car
# Plane
# Car
# Plane
# Boat
# Plane
# Plane
